# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd

# %%
shp = gpd.read_file('phl_adminboundaries_candidate_adm3\phl_admbnda_adm3_psa_namria_20200529.shp')

# %%
shp
# Out:
#       Shape_Leng  Shape_Area         ADM3_EN   ADM3_PCODE ADM3_REF ADM3ALT1EN  \
# 0       1.601219    0.063496         Aborlan  PH175301000     None       None
# 1       1.078749    0.050232    Abra de Ilog  PH175101000     None       None
# 2       0.424301    0.006453          Abucay  PH030801000     None       None
# 3       0.566053    0.011343          Abulug  PH021501000     None       None
# 4       1.013649    0.026124          Abuyog  PH083701000     None       None
# ...          ...         ...             ...          ...      ...        ...
# 1642    4.719512    0.122560  Zamboanga City  PH097332000     None       None
# 1643    0.511917    0.012622    Zamboanguita  PH074625000     None       None
# 1644    0.451962    0.006523        Zaragoza  PH034932000     None       None
# 1645    0.439317    0.003161         Zarraga  PH063047000     None       None
# 1646    0.684150    0.002923       Zumarraga  PH086023000     None       None
#
# ...

# %%
luzon = shp[shp['ADM1_EN'].isin(['Region I','Region II','Region III','Region IV-A','Region IV-B','Region V','Cordillera Administrative Region'])]
visayas = shp[shp['ADM1_EN'].isin(['Region VI','Region VII','Region VIII'])]
mindanao = shp[shp['ADM1_EN'].isin(['Region IX','Region X','Region XI', 'Region XII', 'Region XIII', "Autonomous Region of Muslim Mindanao"])]

# %%
fig,ax = plt.subplots(figsize=(10,10))
shp.plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
fig,ax = plt.subplots(figsize=(10,10))
luzon.plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
fig,ax = plt.subplots(figsize=(10,10))
visayas.plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
fig,ax = plt.subplots(figsize=(10,10))
mindanao.plot(ax=ax)
# Out:
# <AxesSubplot:>
